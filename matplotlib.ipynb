# %%
# %matplotlib inline  #to fit the graph properly in the jupyter notebook
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([4,10, 8, 5,6])

# %%
y=[12, 76, 12, 54]
x=[1, 2,3, 4 ]
plt.plot(x,y)
